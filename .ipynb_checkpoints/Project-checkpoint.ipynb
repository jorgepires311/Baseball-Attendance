# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import datetime
import requests
import json

# %%
# Load CSV Files into Dataframes
games_file = "data/games.csv"
atbats_file = "data/atbats.csv"
player_name_file = "data/player_names.csv"

games_pd = pd.read_csv(games_file)
atbats_pd = pd.read_csv(atbats_file)
player_name_pd = pd.read_csv(player_name_file)

games_atbats_merge_pd = pd.merge(games_pd, atbats_pd, how="left", on=["g_id"])

games_atbats_merge_pd.columns = ['Attendance',
                                 'Final Score',
                                 'Away Team',
                                 'Game Date',
                                 'Elapsed Time',
                                 'Game ID',
                                 'Home Team Score',
                                 'Home Team',
                                 'Game Start Time',
                                 'Umpire 1',
                                 'Umpire 2',
                                 'Umpire 3',
                                 'Umpire HP',
                                 'Venue',
                                 'Weather',
                                 'Wind',
                                 'Delay Time',
                                 'AtBat ID',
                                 'Player ID',
                                 'Event',
                                 'Inning',
                                 'Outs',
                                 'Score of Pitchers Team',
                                 'Pitcher Hand',
                                 'Pitcher ID',
                                 'Batter Stance',
                                 'Top of the Inning'
                                ]
games_atbats_merge_pd.drop(['Umpire 1', 'Umpire 2','Umpire 3','Umpire HP','Outs','Batter Stance'], inplace=True, axis=1, errors='ignore')
games_atbats_merge_pd.head()
# Out:
#    Attendance  Final Score Away Team   Game Date  Elapsed Time    Game ID  \
# 0       35055            3       sln  2015-04-05           184  201500001
# 1       35055            3       sln  2015-04-05           184  201500001
# 2       35055            3       sln  2015-04-05           184  201500001
# 3       35055            3       sln  2015-04-05           184  201500001
# 4       35055            3       sln  2015-04-05           184  201500001
#
#    Home Team Score Home Team Game Start Time          Venue  \
# 0                0       chn         7:17 PM  Wrigley Field
# 1                0       chn         7:17 PM  Wrigley Field
# 2                0       chn         7:17 PM  Wrigley Field
# 3                0       chn         7:17 PM  Wrigley Field
# 4                0       chn         7:17 PM  Wrigley Field
#
#          ...                       Wind Delay Time    AtBat ID  Player ID  \
# 0        ...          7 mph, In from CF          0  2015000001     572761
# 1        ...          7 mph, In from CF          0  2015000002     518792
# 2        ...          7 mph, In from CF          0  2015000003     407812
# 3        ...          7 mph, In from CF          0  2015000004     425509
# 4        ...          7 mph, In from CF          0  2015000005     571431
#
#        Event Inning  Score of Pitchers Team  Pitcher Hand Pitcher ID  \
# 0  Groundout      1                       0             L     452657
# 1     Double      1                       0             L     452657
# 2     Single      1                       0             L     452657
# 3  Strikeout      1                       0             L     452657
# 4  Strikeout      1                       0             L     452657
#
#    Top of the Inning
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
#
# [5 rows x 21 columns]

# %%
games_atbats_merge_pd.columns
# Out:
# Index(['Attendance', 'Final Score', 'Away Team', 'Game Date', 'Elapsed Time',
#        'Game ID', 'Home Team Score', 'Home Team', 'Game Start Time', 'Venue',
#        'Weather', 'Wind', 'Delay Time', 'AtBat ID', 'Player ID', 'Event',
#        'Inning', 'Score of Pitchers Team', 'Pitcher Hand', 'Pitcher ID',
#        'Top of the Inning'],
#       dtype='object')

# %%
# Keala's Player Input Visualization
#Merging games_atbats_merge_pd with the player_name_pd
player_name_pd.columns = ['Player ID', 'First Name','Last Name']
    
player_summary_pd = pd.merge(player_name_pd, games_atbats_merge_pd, how="left", on=["Player ID"])
# player_summary_pd.head()

player_name = input("Which player do you want to look up?")

# %%
#Keala's Venue Visualization

# %%
#Scott's Weather Visualizations - Temp, Conditions, & Wind speed

# %%
#Kelsey's Time Visualizations - Day of the week, & Time of day

# %%
#Jorge's Stats Visualizations - Home scores/Record

# %%
#Jorge's Stat Visualizations - Average Homeruns at home vs Attendance

# %%
#Kelsey's Home Team vs Visiting team Visualization

# Building a dictionary of teams then a data frame based on abbreviation to make it easier to read
# the data; the original data set only had abbreviations

teams_dc = {"Abbreviation": ["laa", "oak", "mil", "chc", "ari",
                            "lad", "sfn", "cle", "sea", "sdn",
                            "tex", "cin", "kcn", "cws", "hou",
                            "tor", "atl", "stl", "col", "mia",
                            "nym", "wsh", "bal", "phi", "pit",
                            "tbn", "bos", "det", "min", "nyy"],
            
            "Team Name": ["Angels", "Athletics", "Brewers", "Cubs", "Diamondbacks", 
                          "Dodgers", "Giants", "Indians", "Mariners", "Padres",
                          "Rangers", "Reds", "Royal", "White Sox", "Astros", 
                         "Blue Jays", "Braves", "Cardinals", "Colorado", "Marlins", 
                          "Mets", "Nationals", "Orioles", "Phillies", "Pirates", 
                          "Rays", "Red Sox", "Tigers", "Twins", "Yankees"]
}

teams_abv_df = pd.DataFrame(teams_dc)
# teams_abv_df.head()

# groupby team name to get average attendance; team name will be x-axis
away_team_df = games_pd
#.set_index("attendance")
sln_away = away_team_df.loc[away_team_df["away_team"] == "sln", :]
sln_away
#away_team_df.head()
# Out:
#       attendance  away_final_score away_team        date  elapsed_time  \
# 0          35055                 3       sln  2015-04-05           184
# 34         26814                 0       sln  2015-04-08           143
# 57         30808                 4       sln  2015-04-10           146
# 72         41525                 4       sln  2015-04-11           156
# 87         41446                 7       sln  2015-04-12           243
# 206        27021                 1       sln  2015-04-21           223
# 221        25771                 7       sln  2015-04-22           171
# 234        26990                 4       sln  2015-04-23           151
# 246        26286                 3       sln  2015-04-24           162
# 259        35919                 5       sln  2015-04-25           181
# 273        32758                 3       sln  2015-04-26           183
# 435        33507                 8       sln  2015-05-08           178
# 450        38068                 5       sln  2015-05-09           154
# 465        34036                 3       sln  2015-05-10           158
# 489        12615                 8       sln  2015-05-12           211
# 504        12313                 0       sln  2015-05-13           167
# 515        15865                 2       sln  2015-05-14           192
# 569        23338                 1       sln  2015-05-18           254
# 582        21157                10       sln  2015-05-19           163
# 597        23726                 9       sln  2015-05-20           163
# 610        32783                 0       sln  2015-05-21           146
# 625        37379                 0       sln  2015-05-22           173
# 641        38676                 2       sln  2015-05-23           100
# 656        36342                 6       sln  2015-05-24           160
# 805        45058                 7       sln  2015-06-04           176
# 819        44649                 2       sln  2015-06-05           142
# 834        47655                 0       sln  2015-06-06           142
# 849        41500                 4       sln  2015-06-07           205
# 859        32043                 3       sln  2015-06-08           159
# 872        33731                 3       sln  2015-06-09           176
# ...          ...               ...       ...         ...           ...
# 8786       17518                 1       sln  2018-07-23           168
# 8801       18379                 4       sln  2018-07-24           212
# 8814       20940                 3       sln  2018-07-25           191
# 8931       26773                 6       sln  2018-08-03           214
# 8947       32473                 8       sln  2018-08-04           201
# 8962       19376                 2       sln  2018-08-05           178
# 8973        8563                 1       sln  2018-08-06           184
# 8989        7230                 3       sln  2018-08-07           154
# 9003        7306                 7       sln  2018-08-08           162
# 9024       29414                 7       sln  2018-08-10           184
# 819             Dodger Stadium          66 degrees, clear       9 mph, L to R
# 834             Dodger Stadium  67 degrees, partly cloudy    7 mph, Out to CF
# 849             Dodger Stadium          73 degrees, sunny       7 mph, L to R
# 859                Coors Field          78 degrees, clear       8 mph, R to L
# 872                Coors Field         73 degrees, cloudy      10 mph, R to L
# ...                        ...                        ...                 ...
# 8786  Great American Ball Park         77 degrees, cloudy    3 mph, Out to CF
# 8801  Great American Ball Park  82 degrees, partly cloudy       5 mph, Varies
# 8814  Great American Ball Park          84 degrees, sunny    4 mph, Out to RF
# 8931                  PNC Park  81 degrees, partly cloudy    4 mph, Out to LF
# 8947                  PNC Park  86 degrees, partly cloudy    9 mph, Out to LF
# 8962                  PNC Park         86 degrees, cloudy       8 mph, R to L
# 8973              Marlins Park  86 degrees, partly cloudy      16 mph, L to R
# 8989              Marlins Park    77 degrees, roof closed         0 mph, None
# 9003              Marlins Park    78 degrees, roof closed         0 mph, None
# 9024          Kauffman Stadium          88 degrees, clear       7 mph, L to R
# 9040          Kauffman Stadium          90 degrees, clear   7 mph, In from RF
# 9055          Kauffman Stadium          90 degrees, sunny      10 mph, R to L
# 9162            Dodger Stadium          77 degrees, clear    5 mph, Out to CF
# 9177            Dodger Stadium          78 degrees, clear       6 mph, L to R
# 9192            Dodger Stadium          77 degrees, clear       6 mph, L to R
# 9215               Coors Field  86 degrees, partly cloudy    4 mph, Out to LF
# 9231               Coors Field         87 degrees, cloudy    2 mph, Out to CF
# 9246               Coors Field  90 degrees, partly cloudy    3 mph, Out to CF
# 9353            Nationals Park  90 degrees, partly cloudy    5 mph, Out to LF
# 9368            Nationals Park  84 degrees, partly cloudy    4 mph, Out to LF
# 9382            Nationals Park          87 degrees, clear    7 mph, Out to LF
# 9400             Comerica Park         67 degrees, cloudy      11 mph, L to R
# 9416             Comerica Park         65 degrees, cloudy      14 mph, L to R
# 9429             Comerica Park         59 degrees, cloudy      16 mph, L to R
# 9534             SunTrust Park  84 degrees, partly cloudy    5 mph, Out to LF
# 9549             SunTrust Park          85 degrees, clear    6 mph, Out to LF
# 9564             SunTrust Park          86 degrees, sunny       3 mph, L to R
# 9681             Wrigley Field       60 degrees, overcast       9 mph, L to R
# 9697             Wrigley Field  59 degrees, partly cloudy         7 mph, Calm
# 9712             Wrigley Field         60 degrees, cloudy       2 mph, Varies
#
#       delay
# 0         0
# 34        0
# 57        0
# 72        0
# 87        0
# 206       0
# 221       0
# 234       0
# 246       0
# 259       0
# 273       0
# 435       0
# 450       0
# 465       0
# 489       0
# 504       0
# 515       0
# 569       0
# 582       0
# 597       0
# 610       0
# 625       0
# 641      70
# 656       0
# 805       0
# 819       0
# 834       0
# 849       0
# 859       0
# 872      67
# ...     ...
# 8786      0
# 8801      0
# 8814      0
# 8931      0
# 8947      0
# 8962      0
# 8973      0
# 8989      0
# 9003      0
# 9024      0
# 9040      0
# 9055      0
# 9162      0
# 9177      0
# 9192      0
# 9215      0
# 9231      0
# 9246      0
# 9353      0
# 9368      0
# 9382      0
# 9400      0
# 9416     28
# 9429      0
# 9534      0
# 9549      0
# 9564      0
# 9681      0
# 9697      0
# 9712      0
#
# [324 rows x 17 columns]

# %%
#Keala's League Visualization - National vs American
